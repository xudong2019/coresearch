# %%
strategy_name = 'tagNetProfitGrowth3YBiggerThan20P'
maxD = 5
inTime = 234
otTime = 474
offStart = ('close_mtx',0)

# %%
import sys
sys.path.append("C:\Program Files\Tinysoft\Analyse.NET")
sys.path.append(r"C:\Users\xudong\Documents\github\coresearch\funcs")
import pymongo
import numpy as np
import pickle
import time
import datetime
import copy
import pandas as pd
from operator import itemgetter
import TSLPy3 as tsl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import talib
import importlib
import rschLib
np.set_printoptions(formatter={'float_kind': "{:.6f}".format})
client = pymongo.MongoClient('localhost', 27017)
db = client.quanLiang
dbt = client.tinySoftData
dtes, tkrs, name, open_mtx, high_mtx, low_mtx, close_mtx,belong, shenwan1, shenwan2, shenwan3, vol_mtx, amount_mtx = rschLib.loadDailyBarMtx()
# get time labels
timeAsFloat, timeLabels, maxM, dayOff = rschLib.getTimeLabels(maxD)
# get trades
trades, tradesUsed, Po, r = rschLib.getTrades(strategy_name, name, tkrs, dtes, maxD, maxM)
# get trade samples by good/bad trades
tradeArea=[inTime,otTime]
result = rschLib.getTradeAnalysisSampleGroups(r, tradeArea)

# draw price change
rschLib.drawPriceChange(r, strategy_name, timeLabels=timeLabels, tp=tradeArea)
rschLib.drawPriceChange(result['rGood10'], strategy_name, timeLabels=timeLabels, title='盈利前10%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rGood20'], strategy_name, timeLabels=timeLabels, title='盈利前20%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rGood30'], strategy_name, timeLabels=timeLabels, title='盈利前30%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rBad10'], strategy_name, timeLabels=timeLabels, title='亏损前10%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rBad20'], strategy_name, timeLabels=timeLabels, title='亏损前20%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rBad30'], strategy_name, timeLabels=timeLabels, title='亏损前30%交易', tp=tradeArea)
# analyze tags
rschLib.analyzeTradeTags(trades, result['rGood10'], result['idxGood10'], '盈利前10%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rGood20'], result['idxGood20'], '盈利前20%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rGood30'], result['idxGood30'], '盈利前30%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rBad10'], result['idxBad10'], '亏损前10%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rBad20'], result['idxBad20'], '亏损前20%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rBad30'], result['idxBad30'], '亏损前30%交易',strategy_name, dtes, name, offStart)

#get tag names
tnames, idxOverLapTagList=rschLib.analyzeTradeTags(trades, r, list(range(len(trades))), '所有交易',strategy_name, dtes, name, offStart)

#draw pnl and tag pnl
importlib.reload(rschLib)
[dtesByTrade, pnlByTrade]=rschLib.getPnl(dtes,tkrs, name, trades, inTime, otTime, dayOff, timeAsFloat, toDatabase='yes', strategy_name=strategy_name)
[dtesPnlAggr,pnlAggr, numTrades] = rschLib.aggregatePnlAndDtes(dtesByTrade, pnlByTrade)
rschLib.drawPNL(dtesPnlAggr, pnlAggr, dtes, strategy_name, toDatabase='yes')
for i in range(len(tnames)):
    tagName = tnames[i]
    [dtesWithTag, pnlWithTag,n] = rschLib.aggregatePnlAndDtes(dtesByTrade[idxOverLapTagList[i]],pnlByTrade[idxOverLapTagList[i]])
    rschLib.drawPNL(dtesWithTag, pnlWithTag, dtes, strategy_name, toDatabase='yes', dateStart=dtesPnl[0], pnlType=tagName)

#analysis of number of trades vs performance
importlib.reload(rschLib)
rschLib.pnlVsNumtrades(pnl, numTrades, strategy_name, toDatabase='yes')
# %load_ext line_profiler
# #%lprun -f getPnl getPnl()
# Out:
# 0 / 67461 1200 2018-10-23 01:31:00 2018-10-29 07:00:00
# 10000 / 67461 1200 2019-01-11 01:31:00 2019-01-17 07:00:00
# 20000 / 67461 1200 2019-04-01 01:31:00 2019-04-08 07:00:00
# 30000 / 67461 1200 2019-06-27 01:31:00 2019-07-03 07:00:00
# 40000 / 67461 1200 2019-10-21 01:31:00 2019-10-25 07:00:00
# 50000 / 67461 1200 2020-02-07 01:31:00 2020-02-13 07:00:00
# 60000 / 67461 1200 2020-05-29 01:31:00 2020-06-04 07:00:00
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 盈利前10%交易 净利润增速连续三年大于20% 99.52 294264.0
# 盈利前10%交易 季度净利润连续三年大于1亿 21.51 687450.0
# 盈利前10%交易 跳空高开 3.14 287635.0
# 盈利前10%交易 突破1年新高(开盘) 0.74 107135
# 盈利前10%交易 突破3个月新高(开盘) 1.53 163610
# 盈利前10%交易 均线多头排列 34.16 3235277.0
# 盈利前10%交易 MACD高于DEA 58.87 5656566
# 盈利前10%交易 MACD大于0 58.87 5656566
# 盈利前10%交易 交易量放大2倍 5.2 674140.0
# 盈利前10%交易 流通市值大于100亿 41.05 1470755.0
# 盈利前10%交易 流通市值大于250亿 19.34 517579.0
# 盈利前10%交易 流通市值大于500亿 8.04 220022.0
# 盈利前10%交易 流通市值小于100亿 58.95 16426389.0
# 盈利前10%交易 流通市值小于50亿 33.07 14855250.0
# 盈利前10%交易 流通市值小于25亿 10.48 12669699.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 盈利前20%交易 净利润增速连续三年大于20% 99.45 294264.0
# 盈利前20%交易 季度净利润连续三年大于1亿 20.9 687450.0
# 盈利前20%交易 跳空高开 2.82 287635.0
# 盈利前20%交易 突破1年新高(开盘) 0.69 107135
# 盈利前20%交易 突破3个月新高(开盘) 1.32 163610
# 盈利前20%交易 均线多头排列 33.29 3235277.0
# 盈利前20%交易 MACD高于DEA 57.19 5656566
# 盈利前20%交易 MACD大于0 57.19 5656566
# 盈利前20%交易 交易量放大2倍 5.54 674140.0
# 盈利前20%交易 流通市值大于100亿 40.5 1470755.0
# 盈利前20%交易 流通市值大于250亿 19.35 517579.0
# 盈利前20%交易 流通市值大于500亿 8.23 220022.0
# 盈利前20%交易 流通市值小于100亿 59.5 16426389.0
# 盈利前20%交易 流通市值小于50亿 33.09 14855250.0
# 盈利前20%交易 流通市值小于25亿 10.1 12669699.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 盈利前30%交易 净利润增速连续三年大于20% 99.44 294264.0
# 盈利前30%交易 季度净利润连续三年大于1亿 20.57 687450.0
# 盈利前30%交易 跳空高开 2.8 287635.0
# 盈利前30%交易 突破1年新高(开盘) 0.66 107135
# 盈利前30%交易 突破3个月新高(开盘) 1.3 163610
# 盈利前30%交易 均线多头排列 33.13 3235277.0
# 盈利前30%交易 MACD高于DEA 56.3 5656566
# 盈利前30%交易 MACD大于0 56.3 5656566
# 盈利前30%交易 交易量放大2倍 5.73 674140.0
# 盈利前30%交易 流通市值大于100亿 40.28 1470755.0
# 盈利前30%交易 流通市值大于250亿 19.01 517579.0
# 盈利前30%交易 流通市值大于500亿 8.12 220022.0
# 盈利前30%交易 流通市值小于100亿 59.72 16426389.0
# 盈利前30%交易 流通市值小于50亿 33.14 14855250.0
# 盈利前30%交易 流通市值小于25亿 9.9 12669699.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 亏损前10%交易 净利润增速连续三年大于20% 99.67 294264.0
# 亏损前10%交易 季度净利润连续三年大于1亿 20.38 687450.0
# 亏损前10%交易 跳空高开 2.45 287635.0
# 亏损前10%交易 突破1年新高(开盘) 0.51 107135
# 亏损前10%交易 突破3个月新高(开盘) 1.32 163610
# 亏损前10%交易 均线多头排列 32.89 3235277.0
# 亏损前10%交易 MACD高于DEA 61.03 5656566
# 亏损前10%交易 MACD大于0 61.03 5656566
# 亏损前10%交易 交易量放大2倍 5.05 674140.0
# 亏损前10%交易 流通市值大于100亿 41.08 1470755.0
# 亏损前10%交易 流通市值大于250亿 19.26 517579.0
# 亏损前10%交易 流通市值大于500亿 8.8 220022.0
# 亏损前10%交易 流通市值小于100亿 58.92 16426389.0
# 亏损前10%交易 流通市值小于50亿 32.94 14855250.0
# 亏损前10%交易 流通市值小于25亿 10.34 12669699.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 亏损前20%交易 净利润增速连续三年大于20% 99.67 294264.0
# 亏损前20%交易 季度净利润连续三年大于1亿 20.33 687450.0
# 亏损前20%交易 跳空高开 2.56 287635.0
# 亏损前20%交易 突破1年新高(开盘) 0.62 107135
# 亏损前20%交易 突破3个月新高(开盘) 1.34 163610
# 亏损前20%交易 均线多头排列 33.19 3235277.0
# 亏损前20%交易 MACD高于DEA 58.81 5656566
# 亏损前20%交易 MACD大于0 58.81 5656566
# 亏损前20%交易 交易量放大2倍 5.45 674140.0
# 亏损前20%交易 流通市值大于100亿 40.32 1470755.0
# 亏损前20%交易 流通市值大于250亿 19.2 517579.0
# 亏损前20%交易 流通市值大于500亿 8.41 220022.0
# 亏损前20%交易 流通市值小于100亿 59.68 16426389.0
# 亏损前20%交易 流通市值小于50亿 33.49 14855250.0
# 亏损前20%交易 流通市值小于25亿 10.53 12669699.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 亏损前30%交易 净利润增速连续三年大于20% 99.61 294264.0
# 亏损前30%交易 季度净利润连续三年大于1亿 20.34 687450.0
# 亏损前30%交易 跳空高开 2.7 287635.0
# 亏损前30%交易 突破1年新高(开盘) 0.62 107135
# 亏损前30%交易 突破3个月新高(开盘) 1.32 163610
# 亏损前30%交易 均线多头排列 33.4 3235277.0
# 亏损前30%交易 MACD高于DEA 57.94 5656566
# 亏损前30%交易 MACD大于0 57.94 5656566
# 亏损前30%交易 交易量放大2倍 5.61 674140.0
# 亏损前30%交易 流通市值大于100亿 40.35 1470755.0
# 亏损前30%交易 流通市值大于250亿 18.93 517579.0
# 亏损前30%交易 流通市值大于500亿 8.13 220022.0
# 亏损前30%交易 流通市值小于100亿 59.65 16426389.0
# 亏损前30%交易 流通市值小于50亿 33.62 14855250.0
# 亏损前30%交易 流通市值小于25亿 10.46 12669699.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 所有交易 净利润增速连续三年大于20% 99.53 294264.0
# 所有交易 季度净利润连续三年大于1亿 20.23 687450.0
# 所有交易 跳空高开 2.79 287635.0
# 所有交易 突破1年新高(开盘) 0.66 107135
# 所有交易 突破3个月新高(开盘) 1.31 163610
# 所有交易 均线多头排列 33.02 3235277.0
# 所有交易 MACD高于DEA 56.15 5656566
# 所有交易 MACD大于0 56.15 5656566
# 所有交易 交易量放大2倍 5.71 674140.0
# 所有交易 流通市值大于100亿 40.33 1470755.0
# 所有交易 流通市值大于250亿 18.96 517579.0
# 所有交易 流通市值大于500亿 8.02 220022.0
# 所有交易 流通市值小于100亿 59.67 16426389.0
# 所有交易 流通市值小于50亿 33.39 14855250.0
# 所有交易 流通市值小于25亿 10.15 12669699.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d85d4508c51c> in <module>
#      51 tnames, idxOverLapTagList=rschLib.analyzeTradeTags(trades, r, list(range(len(trades))), '所有交易',strategy_name, dtes, name, offStart)
#      52 rschLib.drawPNL(dtesPnl, pnl, dtes, strategy_name, toDatabase='yes')
# ---> 53 for i in range(len(tagNames)):
#      54     tl = [trades[q] for q in idxOverLapTagList[i]]
#      55     [dtesWithTag,pnlWithTag,nn]=rschLib.getPnl(dtes,tkrs, name, tl, inTime, otTime, dayOff, timeAsFloat, toDatabase='no', strategy_name=strategy_name)
#
# NameError: name 'tagNames' is not defined

# %%
#draw pnl and tag pnl
rschLib.drawPNL(dtesPnlAggr, pnlAggr, dtes, strategy_name, toDatabase='yes')
for i in range(len(tnames)):
    tagName = tnames[i]
    [dtesWithTag, pnlWithTag,n] = rschLib.aggregatePnlAndDtes(dtesByTrade[idxOverLapTagList[i]],pnlByTrade[idxOverLapTagList[i]])
    rschLib.drawPNL(dtesWithTag, pnlWithTag, dtes, strategy_name, toDatabase='yes', dateStart=dtesPnl[0], pnlType=tagName)

#analysis of number of trades vs performance
importlib.reload(rschLib)
rschLib.pnlVsNumtrades(pnl, numTrades, strategy_name, toDatabase='yes')
# %load_ext line_profiler
# #%lprun -f getPnl getPnl()
