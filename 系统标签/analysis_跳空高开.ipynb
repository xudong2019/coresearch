# %%
strategy_name = 'TagBreak1YHighOpen'
offStart = ('open_mtx',0)

# %%
import sys
sys.path.append("C:\Program Files\Tinysoft\Analyse.NET")
sys.path.append(r"C:\Users\xudong\Documents\github\coresearch\funcs")
import pymongo
import numpy as np
import pickle
import time
import datetime
import copy
import pandas as pd
from operator import itemgetter
import TSLPy3 as tsl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import talib
import importlib
import rschLib
np.set_printoptions(formatter={'float_kind': "{:.6f}".format})
client = pymongo.MongoClient('localhost', 27017)
db = client.quanLiang
dbt = client.tinySoftData
dtes, tkrs, name, open_mtx, high_mtx, low_mtx, close_mtx,belong, shenwan1, shenwan2, shenwan3, vol_mtx, amount_mtx = rschLib.loadDailyBarMtx()

# %%
maxD = 4
inTime = 234
otTime = 614
tradeArea=[inTime,otTime]

# %%
importlib.reload(rschLib)
timeAsFloat, timeLabels, maxM, dayOff = rschLib.getTimeLabels(maxD)
trades, tradesUsed, Po, r = rschLib.getTrades(strategy_name, name, tkrs, dtes, maxD, maxM)
# Out:
# 10000 / 12849 960 2020-07-14 01:31:00 2020-07-17 07:00:00

# %%
importlib.reload(rschLib)
result = rschLib.getTradeAnalysisSampleGroups(r, tradeArea)

# %%
#h = np.max(np.cumsum(r[:, :tradeArea[0]], axis=1), axis=1)
#isZhangtingBeforeTradeArea = h>=0.05
importlib.reload(rschLib)
rschLib.drawPriceChange(r, strategy_name, timeLabels=timeLabels, tp=tradeArea)
rschLib.drawPriceChange(result['rGood10'], strategy_name, timeLabels=timeLabels, title='盈利前10%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rGood20'], strategy_name, timeLabels=timeLabels, title='盈利前20%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rGood30'], strategy_name, timeLabels=timeLabels, title='盈利前30%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rBad10'], strategy_name, timeLabels=timeLabels, title='亏损前10%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rBad10'], strategy_name, timeLabels=timeLabels, title='亏损前20%交易', tp=tradeArea)
rschLib.drawPriceChange(result['rBad10'], strategy_name, timeLabels=timeLabels, title='亏损前30%交易', tp=tradeArea)

# %%
importlib.reload(rschLib)
rschLib.analyzeTradeTags(trades, result['rGood10'], result['idxGood10'], '盈利前10%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rGood20'], result['idxGood20'], '盈利前20%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rGood30'], result['idxGood30'], '盈利前30%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rBad10'], result['idxBad10'], '亏损前10%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rBad20'], result['idxBad20'], '亏损前20%交易',strategy_name, dtes, name, offStart)
rschLib.analyzeTradeTags(trades, result['rBad30'], result['idxBad30'], '亏损前30%交易',strategy_name, dtes, name, offStart)
# Out:
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 盈利前10%交易 净利润增速连续三年大于20% 2.32 294195.0
# 盈利前10%交易 季度净利润连续三年大于1亿 7.5 686976.0
# 盈利前10%交易 跳空高开 16.54 287588.0
# 盈利前10%交易 突破1年新高(开盘) 39.03 107118
# 盈利前10%交易 突破3个月新高(开盘) 39.03 163587
# 盈利前10%交易 均线多头排列 98.79 3234158.0
# 盈利前10%交易 MACD高于DEA 98.68 5654648
# 盈利前10%交易 MACD大于0 98.68 5654648
# 盈利前10%交易 交易量放大2倍 20.51 673934.0
# 盈利前10%交易 流通市值大于100亿 14.88 1469977.0
# 盈利前10%交易 流通市值大于250亿 6.17 517170.0
# 盈利前10%交易 流通市值大于500亿 2.32 219844.0
# 盈利前10%交易 流通市值小于100亿 85.12 16414818.0
# 盈利前10%交易 流通市值小于50亿 72.0 14844080.0
# 盈利前10%交易 流通市值小于25亿 52.48 12659378.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 盈利前20%交易 净利润增速连续三年大于20% 3.14 294195.0
# 盈利前20%交易 季度净利润连续三年大于1亿 7.28 686976.0
# 盈利前20%交易 跳空高开 17.14 287588.0
# 盈利前20%交易 突破1年新高(开盘) 38.97 107118
# 盈利前20%交易 突破3个月新高(开盘) 38.97 163587
# 盈利前20%交易 均线多头排列 98.13 3234158.0
# 盈利前20%交易 MACD高于DEA 98.79 5654648
# 盈利前20%交易 MACD大于0 98.79 5654648
# 盈利前20%交易 交易量放大2倍 20.51 673934.0
# 盈利前20%交易 流通市值大于100亿 14.72 1469977.0
# 盈利前20%交易 流通市值大于250亿 6.23 517170.0
# 盈利前20%交易 流通市值大于500亿 2.92 219844.0
# 盈利前20%交易 流通市值小于100亿 85.28 16414818.0
# 盈利前20%交易 流通市值小于50亿 72.66 14844080.0
# 盈利前20%交易 流通市值小于25亿 51.43 12659378.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 盈利前30%交易 净利润增速连续三年大于20% 3.35 294195.0
# 盈利前30%交易 季度净利润连续三年大于1亿 7.54 686976.0
# 盈利前30%交易 跳空高开 17.21 287588.0
# 盈利前30%交易 突破1年新高(开盘) 38.38 107118
# 盈利前30%交易 突破3个月新高(开盘) 38.38 163587
# 盈利前30%交易 均线多头排列 97.79 3234158.0
# 盈利前30%交易 MACD高于DEA 98.71 5654648
# 盈利前30%交易 MACD大于0 98.71 5654648
# 盈利前30%交易 交易量放大2倍 20.74 673934.0
# 盈利前30%交易 流通市值大于100亿 15.37 1469977.0
# 盈利前30%交易 流通市值大于250亿 6.43 517170.0
# 盈利前30%交易 流通市值大于500亿 2.76 219844.0
# 盈利前30%交易 流通市值小于100亿 84.63 16414818.0
# 盈利前30%交易 流通市值小于50亿 72.21 14844080.0
# 盈利前30%交易 流通市值小于25亿 51.25 12659378.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 亏损前10%交易 净利润增速连续三年大于20% 4.3 294195.0
# 亏损前10%交易 季度净利润连续三年大于1亿 8.16 686976.0
# 亏损前10%交易 跳空高开 18.52 287588.0
# 亏损前10%交易 突破1年新高(开盘) 38.37 107118
# 亏损前10%交易 突破3个月新高(开盘) 38.37 163587
# 亏损前10%交易 均线多头排列 98.02 3234158.0
# 亏损前10%交易 MACD高于DEA 99.34 5654648
# 亏损前10%交易 MACD大于0 99.34 5654648
# 亏损前10%交易 交易量放大2倍 18.41 673934.0
# 亏损前10%交易 流通市值大于100亿 15.66 1469977.0
# 亏损前10%交易 流通市值大于250亿 7.28 517170.0
# 亏损前10%交易 流通市值大于500亿 3.75 219844.0
# 亏损前10%交易 流通市值小于100亿 84.34 16414818.0
# 亏损前10%交易 流通市值小于50亿 72.11 14844080.0
# 亏损前10%交易 流通市值小于25亿 54.47 12659378.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 亏损前20%交易 净利润增速连续三年大于20% 4.19 294195.0
# 亏损前20%交易 季度净利润连续三年大于1亿 8.21 686976.0
# 亏损前20%交易 跳空高开 18.08 287588.0
# 亏损前20%交易 突破1年新高(开盘) 37.1 107118
# 亏损前20%交易 突破3个月新高(开盘) 37.1 163587
# 亏损前20%交易 均线多头排列 98.46 3234158.0
# 亏损前20%交易 MACD高于DEA 98.95 5654648
# 亏损前20%交易 MACD大于0 98.95 5654648
# 亏损前20%交易 交易量放大2倍 18.58 673934.0
# 亏损前20%交易 流通市值大于100亿 16.21 1469977.0
# 亏损前20%交易 流通市值大于250亿 7.5 517170.0
# 亏损前20%交易 流通市值大于500亿 3.53 219844.0
# 亏损前20%交易 流通市值小于100亿 83.79 16414818.0
# 亏损前20%交易 流通市值小于50亿 71.11 14844080.0
# 亏损前20%交易 流通市值小于25亿 51.65 12659378.0
# ['净利润增速连续三年大于20%', '季度净利润连续三年大于1亿', '跳空高开', '突破1年新高(开盘)', '突破3个月新高(开盘)', '均线多头排列', 'MACD高于DEA', 'MACD大于0', '交易量放大2倍', '流通市值大于100亿', '流通市值大于250亿', '流通市值大于500亿', '流通市值小于100亿', '流通市值小于50亿', '流通市值小于25亿']
# 亏损前30%交易 净利润增速连续三年大于20% 4.08 294195.0
# 亏损前30%交易 季度净利润连续三年大于1亿 8.82 686976.0
# 亏损前30%交易 跳空高开 17.61 287588.0
# 亏损前30%交易 突破1年新高(开盘) 37.32 107118
# 亏损前30%交易 突破3个月新高(开盘) 37.32 163587
# 亏损前30%交易 均线多头排列 98.05 3234158.0
# 亏损前30%交易 MACD高于DEA 99.08 5654648
# 亏损前30%交易 MACD大于0 99.08 5654648
# 亏损前30%交易 交易量放大2倍 19.85 673934.0
# 亏损前30%交易 流通市值大于100亿 16.95 1469977.0
# 亏损前30%交易 流通市值大于250亿 7.83 517170.0
# 亏损前30%交易 流通市值大于500亿 3.75 219844.0
# 亏损前30%交易 流通市值小于100亿 83.05 16414818.0
# 亏损前30%交易 流通市值小于50亿 70.26 14844080.0
# 亏损前30%交易 流通市值小于25亿 51.18 12659378.0

# %%
importlib.reload(rschLib)
[dtesPnl,pnl, numTrades]=rschLib.getPnl(dtes,tkrs, name, trades, inTime, otTime, dayOff, timeAsFloat, toDatabase='yes')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-5d83449491cd> in <module>
#       1 importlib.reload(rschLib)
# ----> 2 [dtesPnl,pnl, numTrades]=rschLib.getPnl(dtes,tkrs, name, trades, inTime, otTime, dayOff, timeAsFloat, toDatabase='yes')
#
# ~\Documents\github\coresearch\funcs\rschLib.py in getPnl(dtes, tkrs, name, trades, inTime, otTime, dayOff, timeAsFloat, toDatabase)
#     125                         }
#     126         r = q2['open']/q1['open']-1
# --> 127         print(t['dateIn'], n, din, '价',q1['open'], dot,'价',q2['open'],'利润',np.round(r*1e4)/1e2,'%', '已经开仓', inPosition, '已经平仓', otPosition)
#     128         pnl.append(r)
#     129         dtesPnl.append(t['dateIn'])
#
# UnboundLocalError: local variable 'dot' referenced before assignment

# %%
importlib.reload(rschLib)
rschLib.pnlVsNumtrades(pnl, numTrades)
